# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
age = 32
name = "Python"
print(f"age: {age}")
print(f"name: {name}")
# Out:
# age: 32
# name: Python

# %%
# Type conversion
print(type(age))

age_str=str(age)
print(type(age_str))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## OPERATORS 
a=10
b=5
result = a**b
print(result)
# Out:
# 100000
