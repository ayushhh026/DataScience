# %%
my_set = {1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set.add(8)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
my_set.remove(1)
print(my_set)
# Out:
# {2, 3, 4, 5, 8}

# %%
my_set.pop()
print(my_set)
# Out:
# {3, 4, 5, 8}

# %%
print(3 in my_set)
# Out:
# True

# %%
set1={1,2,3,4,5}
set2={4,5,6,7,8}
print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
