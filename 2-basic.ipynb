# %%
#if elif else
n=1
if n>0:
    print("positive number")
elif n<1:
    print("negative number")
else:
    print("Zero number")
# Out:
# positive number

# %%
#loops
#For loop
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
