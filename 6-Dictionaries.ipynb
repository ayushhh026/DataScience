# %%
student={"name":"Spongebob","age":30,"grade":24}

# %%
# Accessing
print(student["grade"])
print(student["name"])
# Out:
# 24
# Spongebob

# %%
student["age"]=25
student["address"]="India"
print(student)
# Out:
# {'name': 'Spongebob', 'age': 25, 'grade': 24, 'address': 'India'}

# %%
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
