# %%
## READ A FILE
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# Hello What is your name

# %%
#WRITING A FILE 
###OVERWRITING
with open('example.txt','w') as file:
    file.write("Hello World!")

# %%
###APPENDING
lines=["Hello " ,"HII ","Good morning "]
with open ('example.txt','a') as file:
    file.writelines(lines)
